# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %%
data = pd.read_csv("/content/glass.csv")

# %%
data.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
data.tail()
# Out:
#           RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
data.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# min      5.430000    0.000000    0.000000    1.000000
# 25%      8.240000    0.000000    0.000000    1.000000
# 50%      8.600000    0.000000    0.000000    2.000000
# 75%      9.172500    0.000000    0.100000    3.000000
# max     16.190000    3.150000    0.510000    7.000000

# %%
sns.factorplot('Type', data=data, kind="count",size = 5,aspect = 2)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
data.plot(kind='box', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# Finding correlation between the variables in the data

# %%
cor = data.corr(method='pearson')

# %%
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_9a704_row0_col0, #T_9a704_row1_col1, #T_9a704_row2_col2, #T_9a704_row3_col3, #T_9a704_row4_col4, #T_9a704_row5_col5, #T_9a704_row6_col6, #T_9a704_row7_col7, #T_9a704_row8_col8, #T_9a704_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9a704_row0_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_9a704_row0_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_9a704_row0_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_9a704_row0_col4, #T_9a704_row1_col8, #T_9a704_row2_col1, #T_9a704_row2_col3, #T_9a704_row2_col6, #T_9a704_row2_col7, #T_9a704_row2_col9, #T_9a704_row4_col0, #T_9a704_row6_col1, #T_9a704_row6_col5, #T_9a704_row9_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9a704_row0_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_9a704_row0_col6 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_9a704_row0_col7, #T_9a704_row4_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_9a704_row0_col8 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_9a704_row0_col9 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_9a704_row1_col0, #T_9a704_row7_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_9a704_row1_col2, #T_9a704_row2_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_9a704_row1_col3, #T_9a704_row5_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_9a704_row1_col4, #T_9a704_row9_col6 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_9a704_row1_col5, #T_9a704_row9_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_9a704_row1_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_9a704_row1_col7 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_9a704_row1_col9, #T_9a704_row9_col7 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_9a704_row2_col4, #T_9a704_row2_col5, #T_9a704_row9_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_9a704_row2_col8, #T_9a704_row4_col7 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_9a704_row3_col0, #T_9a704_row5_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_9a704_row3_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_9a704_row3_col2, #T_9a704_row6_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_9a704_row3_col4, #T_9a704_row7_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_9a704_row3_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_9a704_row3_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_9a704_row3_col7, #T_9a704_row7_col3 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_9a704_row3_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_9a704_row3_col9 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_9a704_row4_col1, #T_9a704_row4_col6, #T_9a704_row5_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_9a704_row4_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_9a704_row4_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_9a704_row4_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_9a704_row4_col9 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_9a704_row5_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_9a704_row5_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_9a704_row5_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_9a704_row5_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_9a704_row5_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_9a704_row5_col9 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_9a704_row6_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_9a704_row6_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_9a704_row6_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_9a704_row6_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_9a704_row6_col8 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_9a704_row6_col9 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_9a704_row7_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_9a704_row7_col2, #T_9a704_row7_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_9a704_row7_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_9a704_row7_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_9a704_row7_col9 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_9a704_row8_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_9a704_row8_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_9a704_row8_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_9a704_row8_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_9a704_row8_col4, #T_9a704_row8_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_9a704_row8_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_9a704_row8_col6 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_9a704_row8_col9 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_9a704_row9_col1 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_9a704_row9_col3 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_9a704_row9_col4 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_9a704_row9_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9a704_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >RI</th>
#       <th class="col_heading level0 col1" >Na</th>
#       <th class="col_heading level0 col2" >Mg</th>
#       <th class="col_heading level0 col3" >Al</th>
#       <th class="col_heading level0 col4" >Si</th>
#       <th class="col_heading level0 col5" >K</th>
#       <th class="col_heading level0 col6" >Ca</th>
#       <th class="col_heading level0 col7" >Ba</th>
#       <th class="col_heading level0 col8" >Fe</th>
#       <th class="col_heading level0 col9" >Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a704_level0_row0" class="row_heading level0 row0" >RI</th>
#       <td id="T_9a704_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_9a704_row0_col1" class="data row0 col1" >-0.191885</td>
#       <td id="T_9a704_row0_col2" class="data row0 col2" >-0.122274</td>
#       <td id="T_9a704_row0_col3" class="data row0 col3" >-0.407326</td>
#       <td id="T_9a704_row0_col4" class="data row0 col4" >-0.542052</td>
#       <td id="T_9a704_row0_col5" class="data row0 col5" >-0.289833</td>
#       <td id="T_9a704_row0_col6" class="data row0 col6" >0.810403</td>
#       <td id="T_9a704_row0_col7" class="data row0 col7" >-0.000386</td>
#       <td id="T_9a704_row0_col8" class="data row0 col8" >0.143010</td>
#       <td id="T_9a704_row0_col9" class="data row0 col9" >-0.164237</td>
#     </tr>
#     <tr>
#       <th id="T_9a704_level0_row1" class="row_heading level0 row1" >Na</th>
#       <td id="T_9a704_row1_col0" class="data row1 col0" >-0.191885</td>
#       <td id="T_9a704_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_9a704_row1_col2" class="data row1 col2" >-0.273732</td>
#       <td id="T_9a704_row1_col3" class="data row1 col3" >0.156794</td>
#       <td id="T_9a704_row1_col4" class="data row1 col4" >-0.069809</td>
#       <td id="T_9a704_row1_col5" class="data row1 col5" >-0.266087</td>
#       <td id="T_9a704_row1_col6" class="data row1 col6" >-0.275442</td>
#       <td id="T_9a704_row1_col7" class="data row1 col7" >0.326603</td>
#       <td id="T_9a704_row1_col8" class="data row1 col8" >-0.241346</td>
#       <td id="T_9a704_row1_col9" class="data row1 col9" >0.502898</td>
#     </tr>
#     <tr>
#       <th id="T_9a704_level0_row2" class="row_heading level0 row2" >Mg</th>
#       <td id="T_9a704_row2_col0" class="data row2 col0" >-0.122274</td>
#       <td id="T_9a704_row2_col1" class="data row2 col1" >-0.273732</td>
#       <td id="T_9a704_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_9a704_row2_col3" class="data row2 col3" >-0.481799</td>
#       <td id="T_9a704_row2_col4" class="data row2 col4" >-0.165927</td>
#       <td id="T_9a704_row2_col5" class="data row2 col5" >0.005396</td>
#       <td id="T_9a704_row2_col6" c

# %%
scaler = StandardScaler()

# %%
scaler.fit(data.drop('Type',axis=1))
# Out:
# StandardScaler()

# %%
StandardScaler(copy=True, with_mean=True, with_std=True)
# Out:
# StandardScaler()

# %%
#perform transformation
scaled_features = scaler.transform(data.drop('Type',axis=1))
scaled_features
# Out:
# array([[ 0.87286765,  0.28495326,  1.25463857, ..., -0.14576634,
#         -0.35287683, -0.5864509 ],
#        [-0.24933347,  0.59181718,  0.63616803, ..., -0.79373376,
#         -0.35287683, -0.5864509 ],
#        [-0.72131806,  0.14993314,  0.60142249, ..., -0.82894938,
#         -0.35287683, -0.5864509 ],
#        ...,
#        [ 0.75404635,  1.16872135, -1.86551055, ..., -0.36410319,
#          2.95320036, -0.5864509 ],
#        [-0.61239854,  1.19327046, -1.86551055, ..., -0.33593069,
#          2.81208731, -0.5864509 ],
#        [-0.41436305,  1.00915211, -1.86551055, ..., -0.23732695,
#          3.01367739, -0.5864509 ]])

# %%
data_feat = pd.DataFrame(scaled_features,columns=data.columns[:-1])
data_feat.head()
# Out:
#          RI        Na        Mg        Al        Si         K        Ca  \
# 0  0.872868  0.284953  1.254639 -0.692442 -1.127082 -0.671705 -0.145766
# 1 -0.249333  0.591817  0.636168 -0.170460  0.102319 -0.026213 -0.793734
# 2 -0.721318  0.149933  0.601422  0.190912  0.438787 -0.164533 -0.828949
# 3 -0.232831 -0.242853  0.698710 -0.310994 -0.052974  0.112107 -0.519052
# 4 -0.312045 -0.169205  0.650066 -0.411375  0.555256  0.081369 -0.624699
#
#          Ba        Fe
# 0 -0.352877 -0.586451
# 1 -0.352877 -0.586451
# 2 -0.352877 -0.586451
# 3 -0.352877 -0.586451
# 4 -0.352877 -0.586451

# %%
dff = data_feat.drop(['Ca','K'],axis=1) #Removing features - Ca and K 
X_train,X_test,y_train,y_test  = train_test_split(dff,data['Type'],test_size=0.3,random_state=45) 
#setting random state ensures split is same eveytime, so that the results are comparable

# %%
knn = KNeighborsClassifier(n_neighbors=4,metric='manhattan')

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=4)

# %%
KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='manhattan',
                     metric_params=None, n_jobs=None, n_neighbors=4, p=2,
                     weights='uniform')
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=4)

# %%
y_pred = knn.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.69      0.90      0.78        20
#            2       0.85      0.65      0.74        26
#            3       0.00      0.00      0.00         3
#            5       0.25      1.00      0.40         1
#            6       0.50      0.50      0.50         2
#            7       1.00      0.85      0.92        13
#
#     accuracy                           0.74        65
#    macro avg       0.55      0.65      0.56        65
# weighted avg       0.77      0.74      0.74        65

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7384615384615385

# %%
k_range = range(1,25)
k_scores = []
error_rate =[]
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    #kscores - accuracy
    scores = cross_val_score(knn,dff,data['Type'],cv=5,scoring='accuracy')
    k_scores.append(scores.mean())
    
    #error rate
    knn.fit(X_train,y_train)
    y_pred = knn.predict(X_test)
    error_rate.append(np.mean(y_pred!=y_test))

#plot k vs accuracy
plt.plot(k_range,k_scores)
plt.xlabel('value of k - knn algorithm')
plt.ylabel('Cross validated accuracy score')
plt.show()

#plot k vs error rate
plt.plot(k_range,error_rate)
plt.xlabel('value of k - knn algorithm')
plt.ylabel('Error rate')
plt.show()
